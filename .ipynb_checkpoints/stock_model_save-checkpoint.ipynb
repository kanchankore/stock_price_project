# %%
# !pip install streamlit==1.8.1
# Out:
# Collecting streamlit==1.8.1
#   Downloading streamlit-1.8.1-py2.py3-none-any.whl (10.1 MB)
# Requirement already satisfied: attrs in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (21.4.0)
# Requirement already satisfied: python-dateutil in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (2.8.2)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (3.1.27)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (4.11.3)
# Requirement already satisfied: altair>=3.2.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (4.2.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (0.7.1)
# Requirement already satisfied: numpy in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (1.20.3)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (3.20.1)
# Requirement already satisfied: tzlocal in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (4.2)
# Requirement already satisfied: pympler>=0.9 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (1.0.1)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (2.1.9)
# Requirement already satisfied: requests in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (2.27.1)
# Requirement already satisfied: blinker in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (1.5)
# Requirement already satisfied: click<8.1,>=7.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (8.0.4)
# Requirement already satisfied: tornado>=5.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (6.1)
# Requirement already satisfied: packaging in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (21.3)
# Requirement already satisfied: cachetools>=4.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (5.1.0)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (1.4.2)
# Requirement already satisfied: toml in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (0.10.2)
# Requirement already satisfied: semver in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (2.13.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (9.1.0)
# Requirement already satisfied: validators in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (0.20.0)
# Requirement already satisfied: pyarrow in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from streamlit==1.8.1) (8.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil->streamlit==1.8.1) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from gitpython!=3.1.19->streamlit==1.8.1) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=1.4->streamlit==1.8.1) (3.8.0)
# Requirement already satisfied: entrypoints in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from altair>=3.2.0->streamlit==1.8.1) (0.4)
# Requirement already satisfied: toolz in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from altair>=3.2.0->streamlit==1.8.1) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from altair>=3.2.0->streamlit==1.8.1) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from altair>=3.2.0->streamlit==1.8.1) (3.1.2)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1) (5.1.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1) (7.7.1)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1) (6.13.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from tzlocal->streamlit==1.8.1) (0.1.0.post0)
# Requirement already satisfied: tzdata; platform_system == "Windows" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from tzlocal->streamlit==1.8.1) (2022.1)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests->streamlit==1.8.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests->streamlit==1.8.1) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests->streamlit==1.8.1) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests->streamlit==1.8.1) (1.26.9)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from click<8.1,>=7.0->streamlit==1.8.1) (0.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from packaging->streamlit==1.8.1) (3.0.8)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.21.0->streamlit==1.8.1) (2022.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from validators->streamlit==1.8.1) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.8.1) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.8.1) (0.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from jinja2->altair>=3.2.0->streamlit==1.8.1) (2.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (8.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (3.6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (7.3.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (1.6.0)
# Requirement already satisfied: psutil in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (5.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (1.5.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.12.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (49.2.1)
# Requirement already satisfied: pickleshare in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.7.5)
# Requirement already satisfied: backcall in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.18.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (6.4.11)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (4.10.0)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (22.3.0)
# Requirement already satisfied: wcwidth in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.5)
# Requirement already satisfied: asttokens in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.0.5)
# Requirement already satisfied: executing in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.13.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (6.5.0)
# Requirement already satisfied: nbformat in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (5.3.0)
# Requirement already satisfied: argon2-cffi in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (21.3.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" and platform_python_implementation != "PyPy" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (304)
# Requirement already satisfied: pywinpty>=1.1.0; os_name == "nt" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.0.5)
# Requirement already satisfied: bleach in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.8.4)
# Requirement already satisfied: fastjsonschema in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.15.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.21)
# Installing collected packages: streamlit
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.8.0
#     Uninstalling streamlit-1.8.0:
#       Successfully uninstalled streamlit-1.8.0
# Successfully installed streamlit-1.8.1
# WARNING: You are using pip version 20.2.3; however, version 22.2 is available.
# You should consider upgrading via the 'c:\users\acer predator\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install yfinance==0.1.70
# Out:
# Collecting yfinance==0.1.70
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.15 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from yfinance==0.1.70) (1.20.3)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from yfinance==0.1.70) (1.4.2)
# Requirement already satisfied: requests>=2.26 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from yfinance==0.1.70) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from yfinance==0.1.70) (4.8.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from yfinance==0.1.70) (0.0.11)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.0->yfinance==0.1.70) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.0->yfinance==0.1.70) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (2.0.12)
# Requirement already satisfied: six>=1.5 in c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance==0.1.70) (1.16.0)
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.1.74
#     Uninstalling yfinance-0.1.74:
#       Successfully uninstalled yfinance-0.1.74
# Successfully installed yfinance-0.1.70
# WARNING: You are using pip version 20.2.3; however, version 22.2 is available.
# You should consider upgrading via the 'c:\users\acer predator\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install pycaret==2.3.10
# Out:
# Collecting pycaret==2.3.10
#   Downloading pycaret-2.3.10-py3-none-any.whl (320 kB)
#      |████████████████████████████████| 320 kB 32.5 MB/s
# Requirement already satisfied: textblob in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (0.17.1)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 76.3 MB/s
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 54.6 MB/s
# Requirement already satisfied: seaborn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (0.11.2)
# Requirement already satisfied: ipywidgets in /root/venv/lib/python3.7/site-packages (from pycaret==2.3.10) (7.7.0)
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 17.0 MB/s
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting pyod
#   Downloading pyod-0.9.9.tar.gz (116 kB)
#      |████████████████████████████████| 116 kB 80.4 MB/s
# Collecting numba<0.55
#   Downloading numba-0.54.1-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 61.9 MB/s
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 76.0 MB/s
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 54.3 MB/s
# Collecting cufflinks>=0.17.0
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      |████████████████████████████████| 81 kB 20.6 MB/s
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 54.5 MB/s
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 50.3 MB/s
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (1.1.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (3.5.1)
# Collecting mlflow
#   Downloading mlflow-1.25.1-py3-none-any.whl (16.8 MB)
#      |████████████████████████████████| 16.8 MB 53.8 MB/s
# Requirement already satisfied: plotly>=4.4.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (5.6.0)
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 55.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: nltk in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (3.7)
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 9.8 MB/s
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
#      |████████████████████████████████| 274 kB 80.2 MB/s
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 90.8 MB/s
# Requirement already satisfied: IPython in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pycaret==2.3.10) (7.32.0)
# Collecting pyyaml<6.0.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 69.9 MB/s
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
#      |████████████████████████████████| 366 kB 74.0 MB/s
# Collecting pandas-profiling>=2.8.0
#   Downloading pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
#      |████████████████████████████████| 261 kB 81.7 MB/s
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (1.2.5)
# Requirement already satisfied: numpy>=1.16.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlxtend>=0.17.0->pycaret==2.3.10) (1.21.5)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from mlxtend>=0.17.0->pycaret==2.3.10) (47.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn==0.23.2->pycaret==2.3.10) (3.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (5.5.5)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /root/venv/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (3.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /root/venv/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (1.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (4.3.3)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.6.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 67.4 MB/s
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from umap-learn->pycaret==2.3.10) (4.63.0)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pyod->pycaret==2.3.10) (1.16.0)
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 25.3 MB/s
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp37-cp37m-manylinux2014_x86_64.whl (26.3 MB)
#      |████████████████████████████████| 26.3 MB 61.7 MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (1.0.6)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 61.2 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (2.27.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (0.9.0)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 74.1 MB/s
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (3.0.6)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (0.7.7)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from gensim<4.0.0->pycaret==2.3.10) (5.2.1)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/site-packages (from lightgbm>=2.3.1->pycaret==2.3.10) (0.37.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (4.31.2)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (0.11.0)
# Collecting cloudpickle
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (8.0.4)
# Collecting gunicorn; platform_system != "Windows"
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 17.5 MB/s
# Requirement already satisfied: entrypoints in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (0.4)
# Requirement already satisfied: gitpython>=2.1.0 in /root/venv/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (3.1.27)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (4.11.3)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 73.1 MB/s
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 73.7 MB/s
# Requirement already satisfied: sqlparse>=0.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (0.4.2)
# Collecting Flask
#   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 11.0 MB/s
# Requirement already satisfied: pytz in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (2022.1)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.16.6.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Requirement already satisfied: protobuf>=3.7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (3.19.4)
# Requirement already satisfied: sqlalchemy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (1.4.32)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.20.1-py3-none-any.whl (18 kB)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly>=4.4.1->pycaret==2.3.10) (8.0.1)
# Collecting numexpr
#   Downloading numexpr-2.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (379 kB)
#      |████████████████████████████████| 379 kB 84.7 MB/s
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pyLDAvis->pycaret==2.3.10) (3.0.3)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: future in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pyLDAvis->pycaret==2.3.10) (0.18.2)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->pycaret==2.3.10) (2022.3.15)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (2.11.2)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.17.2)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (3.0.28)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.7.5)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Collecting tangled-up-in-unicode==0.1.0
#   Downloading tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 59.0 MB/s
# Collecting markupsafe~=2.0.1
#   Downloading MarkupSafe-2.0.1-cp37-cp37m-manylinux2010_x86_64.whl (31 kB)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (690 kB)
#      |████████████████████████████████| 690 kB 91.7 MB/s
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 22.6 MB/s
# Requirement already satisfied: pydantic>=1.8.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling>=2.8.0->pycaret==2.3.10) (1.8.2)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Requirement already satisfied: tornado>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.3.10) (6.1)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.3.10) (6.1.12)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret==2.3.10) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret==2.3.10) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (6.3.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 70.5 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (1.26.9)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->pycaret==2.3.10) (4.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /root/venv/lib/python3.7/site-packages (from gitpython>=2.1.0->mlflow->pycaret==2.3.10) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret==2.3.10) (3.7.0)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 6.2 MB/s
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 15.2 MB/s
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /shared-libs/python3.7/py/lib/python3.7/site-packages (from alembic->mlflow->pycaret==2.3.10) (5.4.0)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: Werkzeug>=2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from Flask->mlflow->pycaret==2.3.10) (2.0.3)
# Requirement already satisfied: pyjwt>=1.7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret==2.3.10) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret==2.3.10) (3.2.0)
# Requirement already satisfied: tabulate>=0.7.7 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret==2.3.10) (0.8.9)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sqlalchemy->mlflow->pycaret==2.3.10) (1.1.2)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prometheus-flask-exporter->mlflow->pycaret==2.3.10) (0.13.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->IPython->pycaret==2.3.10) (0.7.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->IPython->pycaret==2.3.10) (0.7.1)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret==2.3.10) (0.2.5)
# Collecting networkx>=2.4
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 36.5 MB/s
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret==2.3.10) (21.4.0)
# Collecting imagehash; extra == "type_image_path"
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      |████████████████████████████████| 812 kB 69.6 MB/s
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->pycaret==2.3.10) (22.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret==2.3.10) (0.18.1)
# Requirement already satisfied: nbconvert==6.0.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.8.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.13.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /root/venv/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->pycaret==2.3.10) (5.0.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 65.5 MB/s
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.1.2)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.5.9)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.8.4)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.5.0)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (21.2.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.5.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.5.4)
# Requirement already satisfied: cffi>=1.0.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.15.0)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (2.21)
# Building wheels for collected packages: umap-learn, pyod, cufflinks, pyLDAvis, pynndescent, databricks-cli, sklearn, htmlmin, imagehash
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82819 sha256=52d7917d297a38b220dbd2645618abbc3b9275a052fc73b9dac839f468f4a39f
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-0.9.9-py3-none-any.whl size=139313 sha256=3287edfb73ac9c547f36be33129853a385e6f40830237e59b854f5c040f21acd
#   Stored in directory: /root/.cache/pip/wheels/68/32/f0/0dc3050775e77b6661a116b70817b02b4305fa253269d6d998
#   Building wheel for cufflinks (setup.py) ... done
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67920 sha256=c6f827010dfcb10b465575a3f6a3af14c9b1ab82cbb244f3ac471b4283f180df
#   Stored in directory: /root/.cache/pip/wheels/e1/27/13/3fe67fa7ea7be444b831d117220b3b586b872c9acd4df480d0
#   Building wheel for pyLDAvis (PEP 517) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136897 sha256=51931b1a3d3863f98e46c28e7e172f05ceade22cb612f4927d55f6f411be4efe
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.6-py3-none-any.whl size=53930 sha256=7af58b44b94f3e5f75562ad6e1fc3c1134e713ef9bd7a82db25d80b17ed4dc5d
#   Stored in directory: /root/.cache/pip/wheels/03/f1/56/f80d72741e400345b5a5b50ec3d929aca581bf45e0225d5c50
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.6-py3-none-any.whl size=112628 sha256=367444221309bd21d08b013d6619213329113b8ef3ee08219b7ae626f65a3ebf
#   Stored in directory: /root/.cache/pip/wheels/96/c1/f8/d75a22e789ab6a4dff11f18338c3af4360189aa371295cc934
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1317 sha256=6ae4416c832826d39e3f99f896e100f8404312f359db49cddb1b575ec68d47fa
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27085 sha256=3bfc84bf477724407bc9e6b3aac2c9b71177cd2234e12b4be79f4a60e980f810
#   Stored in directory: /root/.cache/pip/wheels/70/e1/52/5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655
#   Building wheel for imagehash (setup.py) ... done
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295197 sha256=1e6f0c06b68cf03b2a477de1441e898ac398fe4382ac57d933f8e9581bfb3b98
#   Stored in directory: /root/.cache/pip/wheels/4c/d5/59/5e3e297533ddb09407769762985d134135064c6831e29a914e
# Successfully built umap-learn pyod cufflinks pyLDAvis pynndescent databricks-cli sklearn htmlmin imagehash
# ERROR: numba 0.54.1 has requirement numpy<1.21,>=1.17, but you'll have numpy 1.21.5 which is incompatible.
# ERROR: yellowbrick 1.4 has requirement scikit-learn>=1.0.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# ERROR: pandas-profiling 3.1.0 has requirement joblib~=1.0.1, but you'll have joblib 1.1.0 which is incompatible.
# Installing collected packages: scipy, scikit-learn, mlxtend, llvmlite, numba, pynndescent, umap-learn, scikit-plot, patsy, statsmodels, pyod, plac, srsly, catalogue, thinc, spacy, gensim, colorlover, cufflinks, lightgbm, cloudpickle, gunicorn, websocket-client, docker, markupsafe, Mako, alembic, itsdangerous, Flask, databricks-cli, pyyaml, prometheus-flask-exporter, querystring-parser, mlflow, kmodes, numexpr, sklearn, funcy, pyLDAvis, Boruta, yellowbrick, imbalanced-learn, wordcloud, multimethod, tangled-up-in-unicode, missingno, phik, networkx, PyWavelets, imagehash, visions, htmlmin, pandas-profiling, pycaret
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Not uninstalling scipy at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'scipy'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Not uninstalling scikit-learn at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
#     Not uninstalling srsly at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'srsly'. No files were found to uninstall.
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.7
#     Not uninstalling catalogue at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'catalogue'. No files were found to uninstall.
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.15
#     Not uninstalling thinc at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'thinc'. No files were found to uninstall.
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.3
#     Not uninstalling spacy at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'spacy'. No files were found to uninstall.
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.1
#     Not uninstalling markupsafe at /shared-libs/python3.7/py-core/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Not uninstalling pyyaml at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'PyYAML'. No files were found to uninstall.
# Successfully installed Boruta-0.3 Flask-2.1.1 Mako-1.2.0 PyWavelets-1.3.0 alembic-1.7.7 catalogue-1.0.0 cloudpickle-2.0.0 colorlover-0.3.0 cufflinks-0.17.3 databricks-cli-0.16.6 docker-5.0.3 funcy-1.17 gensim-3.8.3 gunicorn-20.1.0 htmlmin-0.1.12 imagehash-4.2.1 imbalanced-learn-0.7.0 itsdangerous-2.1.2 kmodes-0.12.1 lightgbm-3.3.2 llvmlite-0.37.0 markupsafe-2.0.1 missingno-0.5.1 mlflow-1.25.1 mlxtend-0.19.0 multimethod-1.8 networkx-2.6.3 numba-0.54.1 numexpr-2.8.1 pandas-profiling-3.1.0 patsy-0.5.2 phik-0.12.2 plac-1.1.3 prometheus-flask-exporter-0.20.1 pyLDAvis-3.3.1 pycaret-2.3.10 pynndescent-0.5.6 pyod-0.9.9 pyyaml-5.4.1 querystring-parser-1.2.4 scikit-learn-0.23.2 scikit-plot-0.3.7 scipy-1.5.4 sklearn-0.0 spacy-2.3.7 srsly-1.0.5 statsmodels-0.13.2 tangled-up-in-unicode-0.1.0 thinc-7.4.5 umap-learn-0.5.3 visions-0.7.4 websocket-client-1.3.2 wordcloud-1.8.1 yellowbrick-1.4
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install numpy==1.18.5
# Out:
# Collecting numpy==1.18.5
#   Using cached numpy-1.18.5.zip (5.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\acer predator\appdata\local\programs\python\python39\python.exe' 'c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages\pip\_vendor\pep517\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\ACERPR~1\AppData\Local\Temp\tmp2wfbcvew'
#          cwd: C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy
#     Complete output (198 lines):
#     Running from numpy source directory.
#     <string>:461: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy\tools\cythonize.py:75: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       required_version = LooseVersion('0.29.14')
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy\tools\cythonize.py:77: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       if LooseVersion(cython_version) < required_version:
#     Processing numpy/random\_bounded_integers.pxd.in
#     Processing numpy/random\mtrand.pyx
#     Processing numpy/random\_bit_generator.pyx
#     Processing numpy/random\_bounded_integers.pyx.in
#     Processing numpy/random\_common.pyx
#     Processing numpy/random\_generator.pyx
#     Processing numpy/random\_mt19937.pyx
#     Processing numpy/random\_pcg64.pyx
#     Processing numpy/random\_philox.pyx
#     Processing numpy/random\_sfc64.pyx
#     Cythonizing sources
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#       libraries blis not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#       libraries openblas not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries tatlas not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#       libraries satlas not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries ptf77blas,ptcblas,atlas not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#       libraries f77blas,cblas,atlas not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy\numpy\distutils\system_info.py:1896: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       if self._calc_info(blas):
#     blas_info:
#       libraries blas not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy\numpy\distutils\system_info.py:1896: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       if self._calc_info(blas):
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy\numpy\distutils\system_info.py:1896: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       if self._calc_info(blas):
#       NOT AVAILABLE
#
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#       libraries mkl_rt not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#       libraries openblas not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#       libraries openblas,lapack not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#       libraries flame not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries tatlas,tatlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries lapack_atlas not found in C:\
#       libraries tatlas,tatlas not found in C:\
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#       libraries tatlas,tatlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries satlas,satlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries lapack_atlas not found in C:\
#       libraries satlas,satlas not found in C:\
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#       libraries satlas,satlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries ptf77blas,ptcblas,atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries lapack_atlas not found in C:\
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#       libraries ptf77blas,ptcblas,atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries f77blas,cblas,atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\lib
#       libraries lapack_atlas not found in C:\
#       libraries f77blas,cblas,atlas not found in C:\
#       libraries lapack_atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#       libraries f77blas,cblas,atlas not found in c:\users\acer predator\appdata\local\programs\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#       libraries lapack not found in ['c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\lib', 'C:\\', 'c:\\users\\acer predator\\appdata\\local\\programs\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy\numpy\distutils\system_info.py:1730: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-install-3mm_nw8f\numpy\numpy\distutils\system_info.py:1730: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#       NOT AVAILABLE
#
#     C:\Users\Acer Predator\AppData\Local\Temp\pip-build-env-qikjf7jw\overlay\Lib\site-packages\setuptools\_distutils\dist.py:257: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running dist_info
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\users\acer predator\appdata\local\programs\python\python39\python.exe' 'c:\users\acer predator\appdata\local\programs\python\python39\lib\site-packages\pip\_vendor\pep517\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\ACERPR~1\AppData\Local\Temp\tmp2wfbcvew' Check the logs for full command output.
# WARNING: You are using pip version 20.2.3; however, version 22.2 is available.
# You should consider upgrading via the 'c:\users\acer predator\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import streamlit as st
import pandas as pd
import datetime
import numpy as np
from datetime import timedelta
from datetime import datetime
import yfinance as yf
import plotly.graph_objects as go
from pycaret.regression import *

# %%
stock_list = [
    'ONGC.NS', 'UPL.NS', 'ITC.NS', 'SUNPHARMA.NS', 'IOC.NS', 'JSWSTEEL.NS',
    'SBIN.NS', 'SHREECEM.NS', 'HINDUNILVR.NS', 'NTPC.NS', 'HINDALCO.NS',
    'LT.NS', 'BAJFINANCE.NS', 'DIVISLAB.NS', 'TATACONSUM.NS', 'HDFCLIFE.NS',
    'M&M.NS', 'INFY.NS', 'GRASIM.NS', 'WIPRO.NS', 'COALINDIA.NS',
    'BRITANNIA.NS', 'INDUSINDBK.NS', 'BHARTIARTL.NS', 'SBILIFE.NS',
    'ICICIBANK.NS', 'TATASTEEL.NS', 'RELIANCE.NS', 'HCLTECH.NS',
    'BAJAJ-AUTO.NS', 'BPCL.NS', 'TCS.NS', 'NESTLEIND.NS', 'ADANIPORTS.NS',
    'AXISBANK.NS', 'ULTRACEMCO.NS', 'CIPLA.NS', 'TITAN.NS', 'HEROMOTOCO.NS',
    'KOTAKBANK.NS', 'BAJAJFINSV.NS', 'POWERGRID.NS', 'ASIANPAINT.NS',
    'EICHERMOT.NS', 'TATAMOTORS.NS', 'DRREDDY.NS', 'HDFCBANK.NS', 'HDFC.NS',
    'MARUTI.NS'
]

# %%
column_names = ["Date", "Close", "stock_name"]

df = pd.DataFrame(columns = column_names)
df['Date'] = pd.to_datetime(df['Date'])
df["Close"] = df["Close"]
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 column_names = ["Date", "Close", "stock_name"]
# ----> 3 df = pd.DataFrame(columns = column_names)
#       4 df['Date'] = pd.to_datetime(df['Date'])
#       5 df["Close"] = df["Close"]
#
# NameError: name 'pd' is not defined

# %%
end = datetime.today().date()
start = end - timedelta(days=1456)

for i in stock_list:
    stock = yf.download(i,start= start, end=end)
    stock = stock.round({'Close': 3})
    stock = stock.reset_index()[["Date","Close"]]
    stock['stock_name'] = i
    df = df.append(stock)

# %%
df['Close'] = df['Close'].ffill()

# %%
data = df.copy()
data['month'] = [i.month for i in data['Date']]
data['year'] = [i.year for i in data['Date']]
data['day_of_week'] = [i.dayofweek for i in data['Date']]
data['day_of_year'] = [i.dayofyear for i in data['Date']]

data.set_index('Date', inplace=True)

# %%
data.head()

# %%
all_ts = data['stock_name'].unique()
all_results = []
final_model = {}

for i in all_ts:
    df_subset = data[data['stock_name'] == i]
    # initialize setup from pycaret.regression
    s = setup(df_subset, target = 'Close', train_size = 0.95, transform_target = True, data_split_shuffle = False,
              fold_strategy = 'timeseries', fold = 5, ignore_features = ['stock_name'], numeric_features = ['day_of_year', 'year','month', 'day_of_week'],
               silent = True, verbose = False, session_id = 2022)
    # compare all models and select best one based on MAE
    best_model = compare_models(sort = 'MAE', verbose=True)
    
    # capture the compare result grid and store best model in list
    p = pull().iloc[0:1]
    p['stock_name'] = str(i)
    all_results.append(p)
    
    # finalize model i.e. fit on entire data including test set
    f = finalize_model(best_model)
    
    # attach final model to a dictionary
    final_model[i] = f
    
    # save transformation pipeline and model as pickle file 
    save_model(f, model_name='/work/NIFTY50-Stock-Analysis/models/' + str(i), verbose=False)

# %%
# !pip install gitpython
# Out:
# Collecting gitpython
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 23.1 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from gitpython) (4.1.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.2 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.9 gitpython-3.1.27 smmap-5.0.0
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import git
PATH_OF_GIT_REPO = '/work/NIFTY50-Stock-Analysis/.git'  # make sure .git folder is properly configured

repo = git.Repo(PATH_OF_GIT_REPO)
index = repo.index
index.add("models")
index.commit("gitpython deepnote")
remote = repo.remote()
remote.pull(repo.active_branch)
remote.push("master")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import git
#       2 PATH_OF_GIT_REPO = '/work/NIFTY50-Stock-Analysis/.git'  # make sure .git folder is properly configured
#       4 repo = git.Repo(PATH_OF_GIT_REPO)
#
# ModuleNotFoundError: No module named 'git'
